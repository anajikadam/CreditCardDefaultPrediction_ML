# %%
# !pip install pandas==1.3.0
# !pip install numpy==1.18.5
# !pip install imbalanced_learn==0.8.0
# !pip install scipy==1.7.0
# !pip install lightgbm==3.3.0
# !pip install imblearn==0.0
# !pip install scikit_learn==1.0.2
# !pip install lime==0.2.0.1
# !pip install shap==0.40.0
# Out:
# Collecting pandas==1.3.0
#   Downloading pandas-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 34 kB/s  eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/labuser/.local/lib/python3.8/site-packages (from pandas==1.3.0) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/labuser/.local/lib/python3.8/site-packages (from pandas==1.3.0) (1.21.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas==1.3.0) (2019.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.0) (1.14.0)
# ERROR: visions 0.7.4 has requirement networkx>=2.4, but you'll have networkx 2.3 which is incompatible.
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# Successfully installed pandas-1.3.0
# Collecting numpy==1.18.5
#   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 31 kB/s  eta 0:00:01
# ERROR: visions 0.7.4 has requirement networkx>=2.4, but you'll have networkx 2.3 which is incompatible.
# ERROR: tifffile 2022.5.4 has requirement numpy>=1.19.2, but you'll have numpy 1.18.5 which is incompatible.
# ERROR: pyldavis 3.3.1 has requirement numpy>=1.20.0, but you'll have numpy 1.18.5 which is incompatible.
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/home/labuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed numpy-1.18.5
# Requirement already satisfied: imbalanced_learn==0.8.0 in /home/labuser/.local/lib/python3.8/site-packages (0.8.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/labuser/.local/lib/python3.8/site-packages (from imbalanced_learn==0.8.0) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /home/labuser/.local/lib/python3.8/site-packages (from imbalanced_learn==0.8.0) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.24 in /home/labuser/.local/lib/python3.8/site-packages (from imbalanced_learn==0.8.0) (1.0.2)
# Requirement already satisfied: scipy>=0.19.1 in /home/labuser/.local/lib/python3.8/site-packages (from imbalanced_learn==0.8.0) (1.7.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn>=0.24->imbalanced_learn==0.8.0) (3.1.0)
# Requirement already satisfied: scipy==1.7.0 in /home/labuser/.local/lib/python3.8/site-packages (1.7.0)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /home/labuser/.local/lib/python3.8/site-packages (from scipy==1.7.0) (1.18.5)
# Requirement already satisfied: lightgbm==3.3.0 in /home/labuser/.local/lib/python3.8/site-packages (3.3.0)
# Requirement already satisfied: scipy in /home/labuser/.local/lib/python3.8/site-packages (from lightgbm==3.3.0) (1.7.0)
# Requirement already satisfied: numpy in /home/labuser/.local/lib/python3.8/site-packages (from lightgbm==3.3.0) (1.18.5)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from lightgbm==3.3.0) (0.34.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/labuser/.local/lib/python3.8/site-packages (from lightgbm==3.3.0) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm==3.3.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm==3.3.0) (3.1.0)
# Requirement already satisfied: imblearn==0.0 in /home/labuser/.local/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /home/labuser/.local/lib/python3.8/site-packages (from imblearn==0.0) (0.8.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/labuser/.local/lib/python3.8/site-packages (from imbalanced-learn->imblearn==0.0) (1.18.5)
# Requirement already satisfied: scipy>=0.19.1 in /home/labuser/.local/lib/python3.8/site-packages (from imbalanced-learn->imblearn==0.0) (1.7.0)
# Requirement already satisfied: joblib>=0.11 in /home/labuser/.local/lib/python3.8/site-packages (from imbalanced-learn->imblearn==0.0) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.24 in /home/labuser/.local/lib/python3.8/site-packages (from imbalanced-learn->imblearn==0.0) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn==0.0) (3.1.0)
# Requirement already satisfied: scikit_learn==1.0.2 in /home/labuser/.local/lib/python3.8/site-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit_learn==1.0.2) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/labuser/.local/lib/python3.8/site-packages (from scikit_learn==1.0.2) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit_learn==1.0.2) (1.7.0)
# Requirement already satisfied: numpy>=1.14.6 in /home/labuser/.local/lib/python3.8/site-packages (from scikit_learn==1.0.2) (1.18.5)
# Requirement already satisfied: lime==0.2.0.1 in /home/labuser/.local/lib/python3.8/site-packages (0.2.0.1)
# Requirement already satisfied: scikit-learn>=0.18 in /home/labuser/.local/lib/python3.8/site-packages (from lime==0.2.0.1) (1.0.2)
# Requirement already satisfied: scipy in /home/labuser/.local/lib/python3.8/site-packages (from lime==0.2.0.1) (1.7.0)
# Requirement already satisfied: tqdm in /home/labuser/.local/lib/python3.8/site-packages (from lime==0.2.0.1) (4.64.0)
# Requirement already satisfied: numpy in /home/labuser/.local/lib/python3.8/site-packages (from lime==0.2.0.1) (1.18.5)
# Requirement already satisfied: matplotlib in /home/labuser/.local/lib/python3.8/site-packages (from lime==0.2.0.1) (3.4.3)
# Requirement already satisfied: scikit-image>=0.12 in /home/labuser/.local/lib/python3.8/site-packages (from lime==0.2.0.1) (0.19.2)
# Requirement already satisfied: joblib>=0.11 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn>=0.18->lime==0.2.0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn>=0.18->lime==0.2.0.1) (3.1.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib->lime==0.2.0.1) (9.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib->lime==0.2.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib->lime==0.2.0.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib->lime==0.2.0.1) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib->lime==0.2.0.1) (0.11.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (2022.5.4)
# Requirement already satisfied: networkx>=2.2 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (2.3)
# Requirement already satisfied: imageio>=2.4.1 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (2.19.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (21.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->lime==0.2.0.1) (1.14.0)
# Requirement already satisfied: decorator>=4.3.0 in /home/labuser/.local/lib/python3.8/site-packages (from networkx>=2.2->scikit-image>=0.12->lime==0.2.0.1) (5.1.1)
# Requirement already satisfied: shap==0.40.0 in /home/labuser/.local/lib/python3.8/site-packages (0.40.0)
# Requirement already satisfied: scipy in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.7.0)
# Requirement already satisfied: numpy in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.18.5)
# Requirement already satisfied: pandas in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.3.0)
# Requirement already satisfied: scikit-learn in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.0.2)
# Requirement already satisfied: tqdm>4.25.0 in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (4.64.0)
# Requirement already satisfied: numba in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (0.55.1)
# Requirement already satisfied: cloudpickle in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (2.1.0)
# Requirement already satisfied: packaging>20.9 in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (21.3)
# Requirement already satisfied: slicer==0.0.7 in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (0.0.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas->shap==0.40.0) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/labuser/.local/lib/python3.8/site-packages (from pandas->shap==0.40.0) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn->shap==0.40.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn->shap==0.40.0) (3.1.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba->shap==0.40.0) (45.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/labuser/.local/lib/python3.8/site-packages (from numba->shap==0.40.0) (0.38.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/labuser/.local/lib/python3.8/site-packages (from packaging>20.9->shap==0.40.0) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas->shap==0.40.0) (1.14.0)

# %%
# !pip install shap==0.40.0
# Out:
# Requirement already satisfied: shap==0.40.0 in /home/labuser/.local/lib/python3.8/site-packages (0.40.0)
# Requirement already satisfied: cloudpickle in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (2.1.0)
# Requirement already satisfied: pandas in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.3.0)
# Requirement already satisfied: scikit-learn in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.0.2)
# Requirement already satisfied: packaging>20.9 in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (21.3)
# Requirement already satisfied: scipy in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.7.0)
# Requirement already satisfied: tqdm>4.25.0 in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (4.64.0)
# Requirement already satisfied: numba in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (0.55.1)
# Requirement already satisfied: slicer==0.0.7 in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (0.0.7)
# Requirement already satisfied: numpy in /home/labuser/.local/lib/python3.8/site-packages (from shap==0.40.0) (1.18.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas->shap==0.40.0) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/labuser/.local/lib/python3.8/site-packages (from pandas->shap==0.40.0) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn->shap==0.40.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from scikit-learn->shap==0.40.0) (3.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/labuser/.local/lib/python3.8/site-packages (from packaging>20.9->shap==0.40.0) (3.0.9)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba->shap==0.40.0) (45.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/labuser/.local/lib/python3.8/site-packages (from numba->shap==0.40.0) (0.38.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas->shap==0.40.0) (1.14.0)

# %%
# !pip install numpy==1.21.1
# Out:
# Collecting numpy==1.21.1
#   Downloading numpy-1.21.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.8 MB)
#      |████████████████████████████████| 15.8 MB 1.9 MB/s eta 0:00:01    |█████████████████               | 8.4 MB 1.9 MB/s eta 0:00:04
# ERROR: visions 0.7.4 has requirement networkx>=2.4, but you'll have networkx 2.3 which is incompatible.
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/home/labuser/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed numpy-1.21.1

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/labuser/.local/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /home/labuser/.local/lib/python3.8/site-packages (from seaborn) (1.21.1)
# Requirement already satisfied: matplotlib>=2.2 in /home/labuser/.local/lib/python3.8/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in /home/labuser/.local/lib/python3.8/site-packages (from seaborn) (1.7.0)
# Requirement already satisfied: pandas>=0.23 in /home/labuser/.local/lib/python3.8/site-packages (from seaborn) (1.3.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (9.0.0)
# Requirement already satisfied: cycler>=0.10 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/labuser/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=0.23->seaborn) (2019.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.14.0)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /home/labuser/.local/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: numpy in /home/labuser/.local/lib/python3.8/site-packages (from xgboost) (1.21.1)
# Requirement already satisfied: scipy in /home/labuser/.local/lib/python3.8/site-packages (from xgboost) (1.7.0)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /home/labuser/.local/lib/python3.8/site-packages (2.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: libclang>=9.0.1 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: absl-py>=0.4.0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (1.46.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: numpy>=1.14.5 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (1.21.1)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/lib/python3/dist-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorboard~=2.6 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (0.25.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/labuser/.local/lib/python3.8/site-packages (from tensorflow) (3.20.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/labuser/.local/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.1.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard~=2.6->tensorflow) (45.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/labuser/.local/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /home/labuser/.local/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (3.3.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/labuser/.local/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.6.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/labuser/.local/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.8.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2019.11.28)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/labuser/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /home/labuser/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.11.3)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/labuser/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/labuser/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (5.1.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (1.0.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/lib/python3/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.2)

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import math

from scipy.stats import kurtosis
from scipy import stats, special
from scipy.stats import skew

import shap
from lime.lime_tabular import LimeTabularExplainer

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot

# %%
# Importing ML algorithms
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.svm import SVC
import xgboost as xgb
from lightgbm import LGBMClassifier
from sklearn.metrics import mean_squared_error, accuracy_score,confusion_matrix, roc_curve, auc,classification_report, recall_score, precision_score, f1_score,roc_auc_score,auc,roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.utils import resample
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from collections import Counter
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
import tensorflow as tf
import keras
import keras.backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import models
from keras import layers

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- --------------------
# absl-py                      1.0.0
# altair                       4.2.0
# amplitude-tracker            0.0.7
# aniso8601                    9.0.1
# apturl                       0.5.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# astor                        0.8.1
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        19.3.0
# Automat                      0.8.0
# aws-cfn-bootstrap            2.0
# backcall                     0.2.0
# backoff                      1.10.0
# backports.zoneinfo           0.2.1
# base58                       2.1.1
# beautifulsoup4               4.11.1
# bleach                       5.0.0
# blinker                      1.4
# blis                         0.4.1
# bokeh                        2.4.3
# boto3                        1.24.37
# botocore                     1.27.37
# cachetools                   5.1.0
# catalogue                    1.0.0
# catboost                     1.0.4
# category-encoders            2.4.0
# catfish                      1.4.13
# certifi                      2019.11.28
# cffi                         1.14.0
# chardet                      3.0.4
# click                        7.1.2
# cloud-init                   22.1
# cloudpickle                  2.1.0
# colorama                     0.4.3
# command-not-found            0.3
# configobj                    5.0.6
# constantly                   15.1.0
# coolname                     1.1.0
# cramjam                      2.5.0
# cryptography                 2.8
# cupshelpers                  1.0
# cycler                       0.11.0
# cymem                        2.0.6
# databricks-cli               0.17.0
# dbus-python                  1.2.16
# debugpy                      1.6.0
# decorator                    5.1.1
# defer                        1.0.6
# defusedxml                   0.7.1
# distro                       1.4.0
# distro-info                  0.23ubuntu1
# docutils                     0.16
# driverlessai                 1.9.2.1
# ec2-hibinit-agent            1.0.0
# entrypoints                  0.3
# et-xmlfile                   1.1.0
# executing                    0.8.3
# fastavro                     1.4.12
# fastjsonschema               2.15.3
# fastparquet                  0.7.2
# feast                        0.11.0
# filelock                     3.10.6
# Flask                        2.0.1
# Flask-RESTful                0.3.9
# flatbuffers                  2.0
# fsspec                       2022.5.0
# funcy                        1.17
# future                       0.18.2
# gast                         0.4.0
# gensim                       4.2.0
# gitdb                        4.0.9
# GitPython                    3.1.27
# google-api-core              2.8.0
# google-auth                  2.6.6
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# googleapis-common-protos     1.52.0
# graphviz                     0.20
# grpcio                       1.46.1
# gunicorn                     20.1.0
# h2o                          3.32.1.2
# h5py                         3.6.0
# hibagent                     1.0.1
# htmlmin                      0.1.12
# httplib2                     0.14.0
# hyperlink                    19.0.0
# idna                         2.8
# ImageHash                    4.2.1
# imageio                      2.19.2
# imbalanced-learn             0.8.0
# imblearn                     0.0
# importlib-metadata           4.11.3
# impyute                      0.0.8
# incremental                  16.10.1
# ipykernel                    5.3.2
# ipython                      7.16.1
# ipython-genutils             0.2.0
# ipywidgets                   7.5.1
# itsdangerous                 2.1.2
# japanize-matplotlib          1.1.3
# jedi                         0.18.1
# jellyfish                    0.8.8
# Jinja2                       3.0.0
# jmespath                     1.0.1
# joblib                       1.1.0
# json5                        0.9.5
# jsonpatch                    1.22
# jsonpointer                  2.0
# jsonschema                   3.2.0
# jupyter                      1.0.0
# jupyter-client               7.3.1
# jupyter-console              6.4.3
# jupyter-core                 4.10.0
# jupyterlab-pygments          0.2.2
# jupyterlab-widgets           1.1.0
# keras                        2.7.0
# Keras-Preprocessing          1.1.2
# keyring                      18.0.1
# kiwisolver                   1.4.2
# langdetect                   1.0.9
# language-selector            0.1
# launchpadlib                 1.10.13
# lazr.restfulclient           0.14.2
# lazr.uri                     1.0.3
# libclang                     14.0.1
# lightdm-gtk-greeter-settings 1.2.2
# lightgbm                     3.3.0
# lime                         0.2.0.1
# llvmlite                     0.38.1
# lockfile                     0.12.2
# macaroonbakery               1.3.1
# Markdown                     3.3.7
# MarkupSafe                   2.1.1
# marshmallow                  3.17.0
# matplotlib                   3.4.3
# matplotlib-inline            0.1.3
# matplotlib-venn              0.11.6
# menulibre                    2.2.1
# missingno                    0.4.2
# mistune                      0.8.4
# mlfoundry                    0.3.33
# mlxtend                      0.14.0
# mmh3                         3.0.0
# monotonic                    1.6
# more-itertools               4.2.0
# mugshot                      0.4.2
# multimethod                  1.8
# murmurhash                   1.0.7
# nbclient                     0.6.3
# nbconvert                    5.6.1
# nbformat                     5.0.7
# nest-asyncio                 1.5.5
# netifaces                    0.10.4
# networkx                     2.3
# nltk                         3.6.1
# notebook                     6.0.3
# numba                        0.55.1
# numexpr                      2.8.1
# numpy                        1.21.1
# oauthlib                     3.1.0
# olefile                      0.46
# onboard                      1.4.1
# opencv-python                4.5.3.56
# opencv-python-headless       4.4.0.46
# openpyxl                     3.0.10
# opt-einsum                   3.3.0
# packaging                    21.3
# pandas                       1.3.0
# pandas-profiling             3.2.0
# pandavro                     1.5.2
# pandocfilters                1.5.0
# parso                        0.8.3
# patsy                        0.5.2
# pexpect                      4.6.0
# phik                         0.12.2
# pickleshare                  0.7.5
# Pillow                       9.0.0
# pip                          20.0.2
# plac                         1.1.3
# plotly                       4.14.3
# preshed                      3.0.6
# prometheus-client            0.14.1
# prompt-toolkit               3.0.29
# protobuf                     3.20.1
# psutil                       5.9.1
# ptyprocess                   0.7.0
# pure-eval                    0.2.2
# puremagic                    1.14
# pyarrow                      8.0.0
# pyasn1                       0.4.2
# pyasn1-modules               0.2.1
# pycairo                      1.16.2
# pycparser                    2.21
# pycups                       1.9.73
# pydantic                     1.9.1
# pydeck                       0.7.1
# Pygments                     2.12.0
# PyGObject                    3.36.0
# PyHamcrest                   1.9.0
# PyJWT                        1.7.1
# pyLDAvis                     3.3.1
# pymacaroons                  0.13.0
# PyNaCl                       1.3.0
# pyOpenSSL                    19.0.0
# pyparsing                    3.0.9
# pyRFC3339                    1.1
# pyrsistent                   0.15.5
# pyserial                     3.4
# pystache                     0.5.4
# python-apt                   2.0.0+ubuntu0.20.4.7
# python-daemon                2.1.2
# python-dateutil              2.8.2
# python-debian                0.1.36ubuntu1
# pytz                         2019.3
# pytz-deprecation-shim        0.1.0.post0
# PyWavelets                   1.3.0
# pyxdg                        0.26
# PyYAML                       5.3.1
# pyzmq                        22.3.0
# qtconsole                    5.3.0
# QtPy                         2.1.0
# regex                        2022.4.24
# reportlab                    3.5.34
# requests                     2.25.1
# requests-oauthlib            1.3.1
# requests-unixsocket          0.2.0
# retrying                     1.3.3
# rsa                          4.8
# s3transfer                   0.6.0
# scikit-image                 0.19.2
# scikit-learn                 1.0.2
# scipy                        1.7.0
# seaborn                      0.11.2
# SecretStorage                2.3.1
# Send2Trash                   1.8.0
# service-identity             18.1.0
# setuptools                   45.2.0
# sgt-launcher                 0.2.5
# shap                         0.40.0
# simplejson                   3.16.0
# six                          1.14.0
# sklearn                      0.0
# slicer                       0.0.7
# smart-open                   6.0.0
# smmap                        5.0.0
# sos                          4.3
# soupsieve                    2.3.2.post1
# spacy                        2.2.3
# sqlparse                     0.4.2
# srsly                        1.0.5
# ssh-import-id                5.10
# stack-data                   0.2.0
# statsmodels                  0.12.2
# streamlit                    0.85.1
# systemd-python               234
# tabulate                     0.8.9
# tangled-up-in-unicode        0.2.0
# tenacity                     8.0.1
# tensorboard                  2.9.0
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.7.0
# tensorflow-estimator         2.7.0
# tensorflow-io-gcs-filesystem 0.25.0
# termcolor                    1.1.0
# terminado                    0.15.0
# testpath                     0.6.0
# textblob                     0.17.1
# tfy-mlflow-client            0.0.13
# thinc                        7.3.1
# threadpoolctl                3.1.0
# thrift                       0.16.0
# tifffile                     2022.5.4
# tinycss2                     1.1.1
# tinynetrc                    1.3.1
# toml                         0.10.2
# toolz                        0.11.2
# torch                        1.10.2
# torchinfo                    1.6.3
# torchvision                  0.11.3
# tornado                      6.1
# tqdm                         4.64.0
# traitlets                    5.2.1.post0
# Twisted                      18.9.0
# typing-extensions            4.2.0
# tzdata                       2022.1
# tzlocal                      4.2
# ubuntu-advantage-tools       20.3
# ubuntu-drivers-common        0.0.0
# ufw                          0.36
# unattended-upgrades          0.1
# urllib3                      1.25.8
# vaderSentiment               3.3.2
# validators                   0.19.0
# visions                      0.7.4
# wadllib                      1.3.3
# wasabi                       0.9.1
# watchdog                     2.1.8
# wcwidth                      0.2.5
# webencodings                 0.5.1
# Werkzeug                     2.1.2
# wheel                        0.34.2
# whylabs-client               0.3.0
# whylabs-datasketches         2.2.0b1
# whylogs                      0.6.30
# widgetsnbextension           3.5.2
# wordcloud                    1.8.1
# wrapt                        1.14.1
# xcffib                       0.8.1
# xgboost                      1.5.1
# xkit                         0.0.0
# zipp                         1.0.0
# zope.interface               4.7.1

# %%
# !pip freeze > requirementsNB.txt
